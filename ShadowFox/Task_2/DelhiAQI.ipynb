# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/delhiaqi.csv")

# %%
df.head(2)
# Out:
#                   date       co    no    no2    o3    so2   pm2_5    pm10  \
# 0  2023-01-01 00:00:00  1655.58  1.66  39.41  5.90  17.88  169.29  194.64
# 1  2023-01-01 01:00:00  1869.20  6.82  42.16  1.99  22.17  182.84  211.08
#
#     nh3
# 0  5.83
# 1  7.66

# %%
df.shape
# Out:
# (561, 9)

# %%
df.columns
# Out:
# Index(['date', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    561 non-null    object
#  1   co      561 non-null    float64
#  2   no      561 non-null    float64
#  3   no2     561 non-null    float64
#  4   o3      561 non-null    float64
#  5   so2     561 non-null    float64
#  6   pm2_5   561 non-null    float64
#  7   pm10    561 non-null    float64
#  8   nh3     561 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 39.6+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# date     0
# co       0
# no       0
# no2      0
# o3       0
# so2      0
# pm2_5    0
# pm10     0
# nh3      0
# dtype: int64

# %%
df.describe()
# Out:
#                  co          no         no2          o3         so2  \
# count    561.000000  561.000000  561.000000  561.000000  561.000000
# mean    3814.942210   51.181979   75.292496   30.141943   64.655936
# std     3227.744681   83.904476   42.473791   39.979405   61.073080
# min      654.220000    0.000000   13.370000    0.000000    5.250000
# 25%     1708.980000    3.380000   44.550000    0.070000   28.130000
# 50%     2590.180000   13.300000   63.750000   11.800000   47.210000
# 75%     4432.680000   59.010000   97.330000   47.210000   77.250000
# max    16876.220000  425.580000  263.210000  164.510000  511.170000
#
#              pm2_5         pm10         nh3
# count   561.000000   561.000000  561.000000
# mean    358.256364   420.988414   26.425062
# std     227.359117   271.287026   36.563094
# min      60.100000    69.080000    0.630000
# 25%     204.450000   240.900000    8.230000
# 50%     301.170000   340.900000   14.820000
# ...

# %%
df.nunique()
# Out:
# date     561
# co       224
# no       346
# no2      198
# o3       283
# so2      231
# pm2_5    557
# pm10     556
# nh3      269
# dtype: int64

# %%
numerical_columns=df.describe(include=None)

numerical_columns
# Out:
#                  co          no         no2          o3         so2  \
# count    561.000000  561.000000  561.000000  561.000000  561.000000
# mean    3814.942210   51.181979   75.292496   30.141943   64.655936
# std     3227.744681   83.904476   42.473791   39.979405   61.073080
# min      654.220000    0.000000   13.370000    0.000000    5.250000
# 25%     1708.980000    3.380000   44.550000    0.070000   28.130000
# 50%     2590.180000   13.300000   63.750000   11.800000   47.210000
# 75%     4432.680000   59.010000   97.330000   47.210000   77.250000
# max    16876.220000  425.580000  263.210000  164.510000  511.170000
#
#              pm2_5         pm10         nh3
# count   561.000000   561.000000  561.000000
# mean    358.256364   420.988414   26.425062
# std     227.359117   271.287026   36.563094
# min      60.100000    69.080000    0.630000
# 25%     204.450000   240.900000    8.230000
# 50%     301.170000   340.900000   14.820000
# ...

# %%
numerical_columns.columns
# Out:
# Index(['co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3'], dtype='object')

# %%
object_column=df.describe(include='O')

object_column
# Out:
#                        date
# count                   561
# unique                  561
# top     2023-01-01 00:00:00
# freq                      1

# %%
object_column.columns
# Out:
# Index(['date'], dtype='object')

# %%
for i in numerical_columns:

    plt.figure(figsize=(15,8))

    sns.histplot(df[i], kde=True, bins=20, palette='hls')

    plt.xticks(rotation=90)

    plt.show()

# %%
for i in numerical_columns:

    plt.figure(figsize=(15,8))

    sns.displot(df[i], kde=True, bins=20)

    plt.xticks(rotation=90)

    plt.show()

# %%
for i in numerical_columns:

    plt.figure(figsize=(15,8))

    sns.boxplot(x=df[i], data=df,)

    plt.xticks(rotation=90)

    plt.show()

# %%
for i in numerical_columns:

    plt.figure(figsize=(15,8))

    sns.violinplot(x=df[i], data=df, palette='hls')

    plt.xticks(rotation=90)

    plt.show()

# %%
df.head()
# Out:
#                   date       co     no    no2    o3    so2   pm2_5    pm10  \
# 0  2023-01-01 00:00:00  1655.58   1.66  39.41  5.90  17.88  169.29  194.64
# 1  2023-01-01 01:00:00  1869.20   6.82  42.16  1.99  22.17  182.84  211.08
# 2  2023-01-01 02:00:00  2510.07  27.72  43.87  0.02  30.04  220.25  260.68
# 3  2023-01-01 03:00:00  3150.94  55.43  44.55  0.85  35.76  252.90  304.12
# 4  2023-01-01 04:00:00  3471.37  68.84  45.24  5.45  39.10  266.36  322.80
#
#      nh3
# 0   5.83
# 1   7.66
# 2  11.40
# 3  13.55
# 4  14.19

# %%
df['date']=pd.to_datetime(df['date'],format='%Y-%m-%d %H:%M:%S')

# %%
df.date
# Out:
# 0     2023-01-01 00:00:00
# 1     2023-01-01 01:00:00
# 2     2023-01-01 02:00:00
# 3     2023-01-01 03:00:00
# 4     2023-01-01 04:00:00
#               ...
# 556   2023-01-24 04:00:00
# 557   2023-01-24 05:00:00
# 558   2023-01-24 06:00:00
# 559   2023-01-24 07:00:00
# 560   2023-01-24 08:00:00
# Name: date, Length: 561, dtype: datetime64[ns]

# %%
df.head()
# Out:
#                  date       co     no    no2    o3    so2   pm2_5    pm10  \
# 0 2023-01-01 00:00:00  1655.58   1.66  39.41  5.90  17.88  169.29  194.64
# 1 2023-01-01 01:00:00  1869.20   6.82  42.16  1.99  22.17  182.84  211.08
# 2 2023-01-01 02:00:00  2510.07  27.72  43.87  0.02  30.04  220.25  260.68
# 3 2023-01-01 03:00:00  3150.94  55.43  44.55  0.85  35.76  252.90  304.12
# 4 2023-01-01 04:00:00  3471.37  68.84  45.24  5.45  39.10  266.36  322.80
#
#      nh3
# 0   5.83
# 1   7.66
# 2  11.40
# 3  13.55
# 4  14.19

# %%
df['hour']=df['date'].dt.hour

# %%
hourly_avg=df.groupby('hour').mean()

# %%
hourly_avg
# Out:
#                co          no         no2          o3         so2       pm2_5  \
# hour
# 0     2207.437917   11.633750   43.068750   19.621667   26.856250  284.571250
# 1     2405.484583   15.325417   47.425000   14.841250   31.790000  295.627083
# 2     3114.222500   32.671667   56.950000    6.160833   40.123750  336.278750
# 3     3719.489167   54.084167   63.304583    3.154583   46.084583  362.630417
# 4     3448.565833   49.720833   65.360833   11.333750   54.399167  334.481667
# 5     3445.228333   48.405417   66.974583   22.321250   61.870000  332.568750
# 6     3339.530000   38.398750   74.628750   40.485833   70.323333  332.872500
# 7     1833.876667   13.730417   55.785000   86.647083   84.538750  216.307917
# 8     1554.608750    9.418333   50.138333  105.813750   81.042500  194.313750
# 9     1534.835217    7.962609   52.020870  116.335217   85.954348  197.552609
# 10    2277.292174   18.039565   72.583913   89.260000   81.103913  240.183478
# ...

# %%
df.set_index('date', inplace=True)

# %%
df
# Out:
#                           co     no    no2     o3     so2   pm2_5    pm10  \
# date
# 2023-01-01 00:00:00  1655.58   1.66  39.41   5.90   17.88  169.29  194.64
# 2023-01-01 01:00:00  1869.20   6.82  42.16   1.99   22.17  182.84  211.08
# 2023-01-01 02:00:00  2510.07  27.72  43.87   0.02   30.04  220.25  260.68
# 2023-01-01 03:00:00  3150.94  55.43  44.55   0.85   35.76  252.90  304.12
# 2023-01-01 04:00:00  3471.37  68.84  45.24   5.45   39.10  266.36  322.80
# ...                      ...    ...    ...    ...     ...     ...     ...
# 2023-01-24 04:00:00  1762.39   4.64  37.01  33.26   30.52  231.15  289.84
# 2023-01-24 05:00:00  1735.69   6.82  34.96  46.49   34.33  225.08  280.52
# 2023-01-24 06:00:00  1922.61   8.16  40.10  56.51   43.39  242.49  296.07
# 2023-01-24 07:00:00  1361.85   9.05  52.78  71.53  100.14  165.67  191.82
# 2023-01-24 08:00:00  1134.87   8.61  56.89  80.11  110.63  123.76  140.26
#
#                        nh3  hour
# date
# ...

# %%
plt.figure(figsize=(12,6))

sns.lineplot(x=df.index, y=df['o3'],)

plt.title('O3 over time')

plt.xlabel("Date Time")

plt.ylabel("O3")

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(15,8))

sns.scatterplot(x=df.index, y=df['o3'])

plt.title('O3 date ')

plt.xlabel('Datetime')

plt.ylabel('o3')

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(15,8))

sns.lineplot(x=df.index, y=df['o3'])

plt.title('O3 date ')

plt.xlabel('Datetime')

plt.ylabel('o3')

plt.xticks(rotation=90)

plt.show()
